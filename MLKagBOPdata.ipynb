# %%
import pandas as pd

# %%
stats = pd.read_csv('BOPS_16042024000532928.csv')

# %%
stats.head(20)
# Out:
#     COU      Country    CONCEPT                 Indicator FREQUENCY  \
# 0   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 1   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 2   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 3   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 4   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 5   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 6   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 7   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 8   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 9   NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 10  NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 11  NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# 12  NZL  New Zealand  I_BP6_XDC  Total, National Currency         Q
# ...

# %%
import matplotlib

# %%
countries = stats.groupby('Country')

# %%
uk_data = countries.get_group('United Kingdom')
uk_data
# Out:
#       COU         Country    CONCEPT                 Indicator FREQUENCY  \
# 1546  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1547  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1548  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1549  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1550  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1551  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1552  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1553  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1554  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1555  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1556  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# 1557  GBR  United Kingdom  I_BP6_XDC  Total, National Currency         Q
# ...

# %%
uk_data.count()
# Out:
# COU           44
# Country       44
# CONCEPT       44
# Indicator     44
# FREQUENCY     44
# Frequency     44
# TIME          44
# Time          44
# Value         44
# Flag Codes     0
# Flags          0
# dtype: int64

# %%
y = uk_data.Value
y
# Out:
# 1546   -1.632800e+11
# 1547   -1.202540e+11
# 1548   -2.166620e+11
# 1549   -1.953420e+11
# 1550   -4.111280e+11
# 1551   -3.550690e+11
# 1552   -5.061180e+11
# 1553   -4.302350e+11
# 1554   -3.241160e+11
# 1555   -2.927730e+11
# 1556   -3.368330e+11
# 1557   -3.552160e+11
# 1558   -3.618530e+11
# 1559   -3.096130e+11
# 1560   -4.376200e+11
# 1561   -3.929640e+11
# 1562   -4.217100e+11
# 1563   -3.575710e+11
# 1564   -4.924200e+11
# 1565   -4.338130e+11
# 1566   -2.298440e+11
# 1567   -3.139020e+11
# 1568   -4.400300e+10
# 1569   -2.442550e+11
# 1570   -1.355620e+11
# 1571   -1.864880e+11
# 1572   -2.689400e+11
# 1573   -2.659020e+11
# 1574   -3.167440e+11
# 1575   -3.185070e+11
# 1576   -2.853700e+11
# 1577   -2.625190e+11
# 1578   -3.954680e+11
# 1579   -3.894060e+11
# 1580   -5.741600e+11
# 1581   -4.699000e+11
# 1582   -4.015670e+11
# 1583   -4.219640e+11
# 1584   -3.469220e+11
# 1585   -4.847890e+11
# 1586   -7.082160e+11
# 1587   -7.293630e+11
# 1588   -7.433830e+11
# ...

# %%
y.isnull().count()
# Out:
# 1630

# %%
y.dropna()
# Out:
# 0      -1.262180e+11
# 1      -1.305500e+11
# 2      -1.431430e+11
# 3      -1.406630e+11
# 4      -1.451500e+11
#             ...
# 1625   -1.156935e+10
# 1626   -6.116328e+09
# 1627   -4.194764e+09
# 1628   -9.455444e+09
# 1629    8.733004e+08
# Name: Value, Length: 1630, dtype: float64

# %%
uk_data.isnull()
# Out:
#         COU  Country  CONCEPT  Indicator  FREQUENCY  Frequency   TIME   Time  \
# 1546  False    False    False      False      False      False  False  False
# 1547  False    False    False      False      False      False  False  False
# 1548  False    False    False      False      False      False  False  False
# 1549  False    False    False      False      False      False  False  False
# 1550  False    False    False      False      False      False  False  False
# 1551  False    False    False      False      False      False  False  False
# 1552  False    False    False      False      False      False  False  False
# 1553  False    False    False      False      False      False  False  False
# 1554  False    False    False      False      False      False  False  False
# 1555  False    False    False      False      False      False  False  False
# 1556  False    False    False      False      False      False  False  False
# ...

# %%
features = ['Value']
X = uk_data[features]

# %%
uk_data.plot.line(y = 'Value')
# Out:
# <Axes: >

# %%
pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting scikit-learn
#
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# ...
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ---------------------------------------  297.0/301.2 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 301.2/301.2 kB 6.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#     --------------------------------------- 0.7/46.2 MB 15.3 MB/s eta 0:00:03
#    - -------------------------------------- 1.3/46.2 MB 16.1 MB/s eta 0:00:03
#    - -------------------------------------- 1.3/46.2 MB 16.1 MB/s eta 0:00:03
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)

# %%
model = RandomForestRegressor(random_state=1)
model.fit(train_X, train_y)
val_predictions = model.predict(val_X)

# %%
val_mae = mean_absolute_error(val_y, val_predictions)
print(val_mae)
# Out:
# 25553006363.636364

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(val_y, val_predictions)
plt.show()

# %%
residuals = val_y - val_predictions
plt.scatter(val_predictions, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.show()
